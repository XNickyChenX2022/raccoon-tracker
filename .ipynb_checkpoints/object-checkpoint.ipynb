# %%
import torch
import numpy as np
import os
from ultralytics import YOLO
from IPython.display import clear_output
from matplotlib import pyplot as plt
clear_output()

# %%
# !python ./yolov5/train.py --img 640 --epochs 3 --data=./data/raccoon.yaml --weights yolov5s.pt
# Out:
# data
# models
# utils
# train: weights=yolov5s.pt, cfg=, data=./data/raccoon.yaml, hyp=yolov5\data\hyps\hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5\data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5\runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github:  YOLOv5 is out of date by 1 commit. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# Traceback (most recent call last):
#   File "C:\Users\nicky\Yolo\yolov5\train.py", line 771, in <module>
#     main(opt)
# ...

# %%
cd yolov5
# Out:
# C:\Users\nicky\Yolo\yolov5

# %%
# %pwd
# Out:
# 'C:\\Users\\nicky\\Yolo'

# %%
# C:\Users\nicky\Yolo
# !python train.py --data=./data/raccoon.yml --weights yolov5s.pt --img 544
# Out:
# train: weights=yolov5s.pt, cfg=, data=./data/raccoon.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=520, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github:  YOLOv5 is out of date by 1 commit. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5  v7.0-268-gf56355d Python-3.11.7 torch-2.1.2 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# ...

# %%
# !python val.py --weight=./runs/train/exp4/weights/best.pt --data=./data/raccoon.yml --img 520
# Out:
# val: data=./data/raccoon.yml, weights=['./runs/train/exp4/weights/best.pt'], batch_size=32, imgsz=520, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-268-gf56355d Python-3.11.7 torch-2.1.2 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# WARNING  --img-size 520 must be multiple of max stride 32, updating to 544
#
# val: Scanning C:\Users\nicky\Yolo\datasets\raccoon\valid\labels.cache... 18 images, 0 backgrounds, 0 corrupt: 100%|##########| 18/18 [00:00<?, ?it/s]
# val: Scanning C:\Users\nicky\Yolo\datasets\raccoon\valid\labels.cache... 18 images, 0 backgrounds, 0 corrupt: 100%|##########| 18/18 [00:00<?, ?it/s]
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='./runs/train/exp4/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\nicky/.cache\torch\hub\master.zip
# YOLOv5  2024-1-8 Python-3.11.7 torch-2.1.2 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
# %pwd
img = os.path.join('datasets', 'raccoon', 'test', 'images',  'raccoon-10_jpg.rf.4a2795d091c50cee00f639178eae580b.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 640x640 1 raccoon
# Speed: 19.1ms pre-process, 157.0ms inference, 303.2ms NMS per image at shape (1, 3, 640, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
